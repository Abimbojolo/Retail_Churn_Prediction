# %% [markdown]
# <a href="https://colab.research.google.com/github/Abimbojolo/Abimbojolo/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import necessary Library

import numpy as np # linear algebra
import pandas as pd # to process the data,
import matplotlib.pyplot as plt # Data Plotting
import seaborn as sns

# %%
prodata = pd.read_csv('prodata.csv')

# %%
prodata.head(10)
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
# 5       50006      1     0.0             Computer         1             22.0
# 6       50007      1     NaN                Phone         3             11.0
# 7       50008      1     NaN                Phone         1              6.0
# 8       50009      1    13.0                Phone         3              9.0
# 9       50010      1     NaN                Phone         1             31.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# ...

# %%
prodata.describe()
# Out:
#          CustomerID        Churn       Tenure     CityTier  WarehouseToHome  \
# count   5630.000000  5630.000000  5366.000000  5630.000000      5379.000000
# mean   52815.500000     0.168384    10.189899     1.654707        15.639896
# std     1625.385339     0.374240     8.557241     0.915389         8.531475
# min    50001.000000     0.000000     0.000000     1.000000         5.000000
# 25%    51408.250000     0.000000     2.000000     1.000000         9.000000
# 50%    52815.500000     0.000000     9.000000     1.000000        14.000000
# 75%    54222.750000     0.000000    16.000000     3.000000        20.000000
# max    55630.000000     1.000000    61.000000     3.000000       127.000000
#
#        HourSpendOnApp  NumberOfDeviceRegistered  SatisfactionScore  \
# count     5375.000000               5630.000000        5630.000000
# mean         2.931535                  3.688988           3.066785
# std          0.721926                  1.023999           1.380194
# ...

# %% [markdown]
# ## Checking for duplicate Values

# %%
prodata.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##Checking for Null Values

# %%
prodata.isnull().sum()
# Out:
# CustomerID                       0
# Churn                            0
# Tenure                         264
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    265
# CouponUsed                     256
# OrderCount                     258
# DaySinceLastOrder              307
# CashbackAmount                   0
# dtype: int64

# %%
prodata_filled = prodata.fillna(prodata.mean())
# Out:
# <ipython-input-8-11d2e7317be0>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   prodata_filled = prodata.fillna(prodata.mean())

# %%
prodata_filled.isnull().sum()
# Out:
# CustomerID                     0
# Churn                          0
# Tenure                         0
# PreferredLoginDevice           0
# CityTier                       0
# WarehouseToHome                0
# PreferredPaymentMode           0
# Gender                         0
# HourSpendOnApp                 0
# NumberOfDeviceRegistered       0
# PreferedOrderCat               0
# SatisfactionScore              0
# MaritalStatus                  0
# NumberOfAddress                0
# Complain                       0
# OrderAmountHikeFromlastYear    0
# CouponUsed                     0
# OrderCount                     0
# DaySinceLastOrder              0
# CashbackAmount                 0
# dtype: int64

# %%
# Specify the file path where you want to save the CSV file
csv_file_path = '/content/drive/MyDrive/prooj.csv'  # Make sure to specify the correct path in Google Colab

# Write the DataFrame to the CSV file
prodata_filled.to_csv(csv_file_path, index=False)

# %%
prodata_filled.dtypes
# Out:
# CustomerID                       int64
# Churn                            int64
# Tenure                         float64
# PreferredLoginDevice            object
# CityTier                         int64
# WarehouseToHome                float64
# PreferredPaymentMode            object
# Gender                          object
# HourSpendOnApp                 float64
# NumberOfDeviceRegistered         int64
# PreferedOrderCat                object
# SatisfactionScore                int64
# MaritalStatus                   object
# NumberOfAddress                  int64
# Complain                         int64
# OrderAmountHikeFromlastYear    float64
# CouponUsed                     float64
# OrderCount                     float64
# DaySinceLastOrder              float64
# CashbackAmount                   int64
# dtype: object

# %%
prodata_filled[['Tenure']].boxplot()
# Out:
# <Axes: >

# %%
prodata_filled[['WarehouseToHome']].boxplot()
# Out:
# <Axes: >

# %%
prodata_filled[['CityTier']].boxplot()
# Out:
# <Axes: >

# %%
prodata_filled.head(17)
# Out:
#     CustomerID  Churn     Tenure PreferredLoginDevice  CityTier  \
# 0        50001      1   4.000000         Mobile Phone         3
# 1        50002      1  10.189899                Phone         1
# 2        50003      1  10.189899                Phone         1
# 3        50004      1   0.000000                Phone         3
# 4        50005      1   0.000000                Phone         1
# 5        50006      1   0.000000             Computer         1
# 6        50007      1  10.189899                Phone         3
# 7        50008      1  10.189899                Phone         1
# 8        50009      1  13.000000                Phone         3
# 9        50010      1  10.189899                Phone         1
# 10       50011      1   4.000000         Mobile Phone         1
# 11       50012      1  11.000000         Mobile Phone         1
# 12       50013      1   0.000000                Phone         1
# 13       50014      1   0.000000                Phone         1
# ...

# %%
# Specify the file path where you want to save the CSV file
csv_file_path = '/content/drive/MyDrive/prooj.csv'  # Make sure to specify the correct path in Google Colab

# Write the DataFrame to the CSV file
prodata_filled.to_csv(csv_file_path, index=False)

# %%
from numpy.core.fromnumeric import prod
# Replace a value in the 'Category' column
prodata_filled['PreferredLoginDevice'] = prodata_filled['PreferredLoginDevice'].replace('Phone', 'MobilePhone')

# Print the updated DataFrame
print(prodata_filled)
# Out:
#       CustomerID  Churn     Tenure PreferredLoginDevice  CityTier  \
# 0          50001      1   4.000000         Mobile Phone         3
# 1          50002      1  10.189899          MobilePhone         1
# 2          50003      1  10.189899          MobilePhone         1
# 3          50004      1   0.000000          MobilePhone         3
# 4          50005      1   0.000000          MobilePhone         1
# ...          ...    ...        ...                  ...       ...
# 5625       55626      0  10.000000             Computer         1
# 5626       55627      0  13.000000         Mobile Phone         1
# 5627       55628      0   1.000000         Mobile Phone         1
# 5628       55629      0  23.000000             Computer         3
# 5629       55630      0   8.000000         Mobile Phone         1
#
#       WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 0                 6.0           Debit Card  Female        3.000000
# ...

# %%
prodata_filled.head()
# Out:
#    CustomerID  Churn     Tenure PreferredLoginDevice  CityTier  \
# 0       50001      1   4.000000         Mobile Phone         3
# 1       50002      1  10.189899          MobilePhone         1
# 2       50003      1  10.189899          MobilePhone         1
# 3       50004      1   0.000000          MobilePhone         3
# 4       50005      1   0.000000          MobilePhone         1
#
#    WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 0              6.0           Debit Card  Female        3.000000
# 1              8.0                  UPI    Male        3.000000
# 2             30.0           Debit Card    Male        2.000000
# 3             15.0           Debit Card    Male        2.000000
# 4             12.0                   CC    Male        2.931535
#
#    NumberOfDeviceRegistered    PreferedOrderCat  SatisfactionScore  \
# 0                         3  Laptop & Accessory                  2
# ...

# %% [markdown]
# ## Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

#create instance of label encoder
lab = LabelEncoder()

#perform label encoding on 'PreferredLoginDevice' column
prodata_filled['PreferredLoginDevice'] = lab.fit_transform(prodata_filled['PreferredLoginDevice'])

# %%
#perform label encoding on 'PreferredLoginDevice' column
prodata_filled['PreferredPaymentMode'] = lab.fit_transform(prodata_filled['PreferredPaymentMode'])

# %%
#perform label encoding on 'PreferredLoginDevice' column
prodata_filled['Gender'] = lab.fit_transform(prodata_filled['Gender'])

# %%
#perform label encoding on 'PreferredLoginDevice' column
prodata_filled['PreferedOrderCat'] = lab.fit_transform(prodata_filled['PreferedOrderCat'])

# %%
#perform label encoding on 'PreferredLoginDevice' column
prodata_filled['MaritalStatus'] = lab.fit_transform(prodata_filled['MaritalStatus'])

# %%
prodata_filled.head()
# Out:
#    CustomerID  Churn     Tenure  PreferredLoginDevice  CityTier  \
# 0       50001      1   4.000000                     1         3
# 1       50002      1  10.189899                     2         1
# 2       50003      1  10.189899                     2         1
# 3       50004      1   0.000000                     2         3
# 4       50005      1   0.000000                     2         1
#
#    WarehouseToHome  PreferredPaymentMode  Gender  HourSpendOnApp  \
# 0              6.0                     4       0        3.000000
# 1              8.0                     6       1        3.000000
# 2             30.0                     4       1        2.000000
# 3             15.0                     4       1        2.000000
# 4             12.0                     0       1        2.931535
#
#    NumberOfDeviceRegistered  PreferedOrderCat  SatisfactionScore  \
# 0                         3                 2                  2
# ...

# %%
prodata_filled.dtypes
# Out:
# CustomerID                       int64
# Churn                            int64
# Tenure                         float64
# PreferredLoginDevice             int64
# CityTier                         int64
# WarehouseToHome                float64
# PreferredPaymentMode             int64
# Gender                           int64
# HourSpendOnApp                 float64
# NumberOfDeviceRegistered         int64
# PreferedOrderCat                 int64
# SatisfactionScore                int64
# MaritalStatus                    int64
# NumberOfAddress                  int64
# Complain                         int64
# OrderAmountHikeFromlastYear    float64
# CouponUsed                     float64
# OrderCount                     float64
# DaySinceLastOrder              float64
# CashbackAmount                   int64
# dtype: object

# %% [markdown]
# # Check for Outlier

# %%
# Calculate the IQR for each column
Q1 = prodata_filled.quantile(0.25)
Q3 = prodata_filled.quantile(0.75)
IQR = Q3 - Q1
# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
# Identify outliers in each column
outliers = (prodata_filled < lower_bound) | (prodata_filled > upper_bound)
# Get columns with outliers
columns_with_outliers = outliers.any()
# Print columns with outliers
print(columns_with_outliers)
# Out:
# CustomerID                     False
# Churn                           True
# Tenure                          True
# PreferredLoginDevice           False
# CityTier                       False
# WarehouseToHome                 True
# PreferredPaymentMode            True
# Gender                         False
# HourSpendOnApp                  True
# NumberOfDeviceRegistered        True
# PreferedOrderCat               False
# SatisfactionScore              False
# MaritalStatus                  False
# NumberOfAddress                 True
# Complain                       False
# OrderAmountHikeFromlastYear     True
# CouponUsed                      True
# OrderCount                      True
# DaySinceLastOrder               True
# CashbackAmount                  True
# dtype: bool

# %%
# Count the number of outliers per column
outliers_count = outliers.sum()

# Print the number of outliers per column
print(outliers_count)
# Out:
# CustomerID                        0
# Churn                           948
# Tenure                            4
# PreferredLoginDevice              0
# CityTier                          0
# WarehouseToHome                   2
# PreferredPaymentMode           1052
# Gender                            0
# HourSpendOnApp                    6
# NumberOfDeviceRegistered        397
# PreferedOrderCat                  0
# SatisfactionScore                 0
# MaritalStatus                     0
# NumberOfAddress                   4
# Complain                          0
# OrderAmountHikeFromlastYear      33
# CouponUsed                      629
# OrderCount                      703
# DaySinceLastOrder                62
# CashbackAmount                  447
# dtype: int64

# %%
prodat = prodata_filled

# %%
prodata_filled.head()
# Out:
#    CustomerID  Churn     Tenure  PreferredLoginDevice  CityTier  \
# 0       50001      1   4.000000                     1         3
# 1       50002      1  10.189899                     2         1
# 2       50003      1  10.189899                     2         1
# 3       50004      1   0.000000                     2         3
# 4       50005      1   0.000000                     2         1
#
#    WarehouseToHome  PreferredPaymentMode  Gender  HourSpendOnApp  \
# 0              6.0                     4       0        3.000000
# 1              8.0                     6       1        3.000000
# 2             30.0                     4       1        2.000000
# 3             15.0                     4       1        2.000000
# 4             12.0                     0       1        2.931535
#
#    NumberOfDeviceRegistered  PreferedOrderCat  SatisfactionScore  \
# 0                         3                 2                  2
# ...

# %%
# Remove the column
prodat.drop('Churn', axis=1, inplace=True)

# %%
prodat[outliers] = np.nan
df_cleaned = prodat.fillna(prodat.mean())

# Print the DataFrame after replacing outliers with mean values
print(df_cleaned)
# Out:
#       CustomerID     Tenure  PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0          50001   4.000000                     1         3              6.0
# 1          50002  10.189899                     2         1              8.0
# 2          50003  10.189899                     2         1             30.0
# 3          50004   0.000000                     2         3             15.0
# 4          50005   0.000000                     2         1             12.0
# ...          ...        ...                   ...       ...              ...
# 5625       55626  10.000000                     0         1             30.0
# 5626       55627  13.000000                     1         1             13.0
# 5627       55628   1.000000                     1         1             11.0
# 5628       55629  23.000000                     0         3              9.0
# 5629       55630   8.000000                     1         1             15.0
#
# ...

# %%
df_cleaned.head()
# Out:
#    CustomerID     Tenure  PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001   4.000000                     1         3              6.0
# 1       50002  10.189899                     2         1              8.0
# 2       50003  10.189899                     2         1             30.0
# 3       50004   0.000000                     2         3             15.0
# 4       50005   0.000000                     2         1             12.0
#
#    PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0              4.000000       0        3.000000                       3.0
# 1              3.741153       1        3.000000                       4.0
# 2              4.000000       1        2.000000                       4.0
# 3              4.000000       1        2.000000                       4.0
# 4              3.741153       1        2.931535                       3.0
#
#    PreferedOrderCat  SatisfactionScore  MaritalStatus  NumberOfAddress  \
# ...

# %%
prodata.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %%
# Add back the dropped column
df_clean = pd.concat([df_cleaned, prodata['Churn']], axis=1)

# Print the DataFrame with the added column
print(df_clean)
# Out:
#       CustomerID     Tenure  PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0          50001   4.000000                     1         3              6.0
# 1          50002  10.189899                     2         1              8.0
# 2          50003  10.189899                     2         1             30.0
# 3          50004   0.000000                     2         3             15.0
# 4          50005   0.000000                     2         1             12.0
# ...          ...        ...                   ...       ...              ...
# 5625       55626  10.000000                     0         1             30.0
# 5626       55627  13.000000                     1         1             13.0
# 5627       55628   1.000000                     1         1             11.0
# 5628       55629  23.000000                     0         3              9.0
# 5629       55630   8.000000                     1         1             15.0
#
# ...

# %%
df_clean.head()
# Out:
#    CustomerID     Tenure  PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001   4.000000                     1         3              6.0
# 1       50002  10.189899                     2         1              8.0
# 2       50003  10.189899                     2         1             30.0
# 3       50004   0.000000                     2         3             15.0
# 4       50005   0.000000                     2         1             12.0
#
#    PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0              4.000000       0        3.000000                       3.0
# 1              3.741153       1        3.000000                       4.0
# 2              4.000000       1        2.000000                       4.0
# 3              4.000000       1        2.000000                       4.0
# 4              3.741153       1        2.931535                       3.0
#
#    PreferedOrderCat  SatisfactionScore  MaritalStatus  NumberOfAddress  \
# ...

# %%
df_clean[['Tenure']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# # Min-Max Scaler

# %%
# Function for Min-Max scaling
def min_max_scaler(x):
    return (x - x.min()) / (x.max() - x.min())

# Columns to apply Min-Max scaling
columns_to_scale = ["WarehouseToHome", "Tenure", "CashbackAmount"]

# Apply Min-Max scaling to the specified columns
df_clean[columns_to_scale] = df_clean[columns_to_scale].apply(min_max_scaler)

# Print the scaled dataset
print(df_clean)
# Out:
#       CustomerID    Tenure  PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0          50001  0.129032                     1         3         0.032258
# 1          50002  0.328706                     2         1         0.096774
# 2          50003  0.328706                     2         1         0.806452
# 3          50004  0.000000                     2         3         0.322581
# 4          50005  0.000000                     2         1         0.225806
# ...          ...       ...                   ...       ...              ...
# 5625       55626  0.322581                     0         1         0.806452
# 5626       55627  0.419355                     1         1         0.258065
# 5627       55628  0.032258                     1         1         0.193548
# 5628       55629  0.741935                     0         3         0.129032
# 5629       55630  0.258065                     1         1         0.322581
#
# ...

# %% [markdown]
# ## Feature Selection and Correlation

# %%
df_clean.corr()
# Out:
#                              CustomerID    Tenure  PreferredLoginDevice  \
# CustomerID                     1.000000  0.028224             -0.148079
# Tenure                         0.028224  1.000000             -0.083168
# PreferredLoginDevice          -0.148079 -0.083168              1.000000
# CityTier                       0.003239 -0.062184             -0.074136
# WarehouseToHome                0.059693 -0.028343             -0.022751
# PreferredPaymentMode          -0.049818 -0.054445              0.000532
# Gender                         0.004251 -0.045232              0.007272
# HourSpendOnApp                 0.584417 -0.023744             -0.079504
# NumberOfDeviceRegistered       0.364453 -0.018104             -0.080106
# PreferedOrderCat               0.085802 -0.172111              0.165255
# SatisfactionScore             -0.033146 -0.010449              0.051483
# MaritalStatus                  0.124088 -0.101765             -0.003821
# ...

# %%
# Plotting HeatMap

sns.heatmap(df_clean.corr())
# Out:
# <Axes: >

# %% [markdown]
# # Data Exploration

# %%
df_clean.head()
# Out:
#    CustomerID    Tenure  PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001  0.129032                     1         3         0.032258
# 1       50002  0.328706                     2         1         0.096774
# 2       50003  0.328706                     2         1         0.806452
# 3       50004  0.000000                     2         3         0.322581
# 4       50005  0.000000                     2         1         0.225806
#
#    PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0              4.000000       0        3.000000                       3.0
# 1              3.741153       1        3.000000                       4.0
# 2              4.000000       1        2.000000                       4.0
# 3              4.000000       1        2.000000                       4.0
# 4              3.741153       1        2.931535                       3.0
#
#    PreferedOrderCat  SatisfactionScore  MaritalStatus  NumberOfAddress  \
# ...

# %% [markdown]
# # Write File to CSV

# %%
# Specify the file path where you want to save the CSV file
csv_file_path = '/content/drive/MyDrive/project.csv'  # Make sure to specify the correct path in Google Colab

# Write the DataFrame to the CSV file
df_clean.to_csv(csv_file_path, index=False)

# %% [markdown]
# ## Univariate Selection (Dependent and Independent Feature Selection)

# %%
X = df_clean.iloc[:,:-1]
Y = df_clean['Churn']

# %%
X.head()
# Out:
#    CustomerID    Tenure  PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001  0.129032                     1         3         0.032258
# 1       50002  0.328706                     2         1         0.096774
# 2       50003  0.328706                     2         1         0.806452
# 3       50004  0.000000                     2         3         0.322581
# 4       50005  0.000000                     2         1         0.225806
#
#    PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0              4.000000       0        3.000000                       3.0
# 1              3.741153       1        3.000000                       4.0
# 2              4.000000       1        2.000000                       4.0
# 3              4.000000       1        2.000000                       4.0
# 4              3.741153       1        2.931535                       3.0
#
#    PreferedOrderCat  SatisfactionScore  MaritalStatus  NumberOfAddress  \
# ...

# %%
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Churn, dtype: int64

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(X,Y)
# Out:
# ExtraTreesClassifier()

# %%
print(model.feature_importances_)
# Out:
# [0.01574949 0.16344941 0.04022301 0.03281025 0.06423735 0.05137964
#  0.03264216 0.03161082 0.0355525  0.05767109 0.0545581  0.04477221
#  0.06293145 0.07637227 0.05686039 0.02021691 0.03301314 0.06355261
#  0.06239721]

# %%
ranked_features = pd.Series(model.feature_importances_,index=X.columns)
ranked_features.nlargest(12).plot(kind='barh')
plt.show()

# %%
import seaborn as sns
corr = df_clean.iloc[:,:-1].corr()
top_features = corr.index
plt.figure(figsize=(20,20))
sns.heatmap(df_clean[top_features].corr(), annot=True)
# Out:
# <Axes: >

# %%
threshold = 0.5

# %%
# Define and remove correlated features

def correlation(dataset, threshold):
  col_corr = set()    #Set of all the names of correslated columns
  corr_matrix = dataset.corr()
  for i in range(len(corr_matrix.columns)):
    for j in range(i):
      if abs(corr_matrix.iloc[i,j]) > threshold:
        colname = corr_matrix.columns[i] # get the name of column
        col_corr.add(colname)
  return col_corr

# %%
correlation(df_clean.iloc[:, :-1], threshold)
# Out:
# {'CashbackAmount', 'HourSpendOnApp'}

# %% [markdown]
# ## Information Gain

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
mutual_info = mutual_info_classif(X,Y)

# %%
mutual_data = pd.Series(mutual_info, index=X.columns)
mutual_data.sort_values(ascending=False)
# Out:
# Tenure                         0.117811
# CashbackAmount                 0.032941
# Complain                       0.032796
# PreferedOrderCat               0.026497
# CustomerID                     0.023817
# MaritalStatus                  0.017800
# DaySinceLastOrder              0.016501
# SatisfactionScore              0.012859
# WarehouseToHome                0.009296
# CouponUsed                     0.006067
# OrderAmountHikeFromlastYear    0.005264
# NumberOfDeviceRegistered       0.003994
# PreferredPaymentMode           0.003558
# CityTier                       0.002018
# PreferredLoginDevice           0.000797
# HourSpendOnApp                 0.000204
# Gender                         0.000000
# NumberOfAddress                0.000000
# OrderCount                     0.000000
# dtype: float64

# %% [markdown]
# ## Dropping Unnnessary Column

# %%
# Dropping the irrelevant Column

X = X.drop(['CustomerID',	'PreferredLoginDevice',	'CityTier',	'PreferredPaymentMode',	'Gender', 'CouponUsed', 'HourSpendOnApp', 'NumberOfDeviceRegistered', 'NumberOfAddress'], axis=1)

# %%
X.head()
# Out:
#      Tenure  WarehouseToHome  PreferedOrderCat  SatisfactionScore  \
# 0  0.129032         0.032258                 2                  2
# 1  0.328706         0.096774                 3                  3
# 2  0.328706         0.806452                 3                  3
# 3  0.000000         0.322581                 2                  5
# 4  0.000000         0.225806                 3                  5
#
#    MaritalStatus  Complain  OrderAmountHikeFromlastYear  OrderCount  \
# 0              2         1                         11.0         1.0
# 1              2         1                         15.0         1.0
# 2              2         1                         14.0         1.0
# 3              2         0                         23.0         1.0
# 4              2         0                         11.0         1.0
#
#    DaySinceLastOrder  CashbackAmount
# 0                5.0        0.415789
# 1                0.0        0.210526
# 2                3.0        0.205263
# ...

# %%
# train_x = X[:80]
# train_y = Y[:80]

# test_x = X[80:]
# test_y = Y[80:]

# %% [markdown]
# # Handling Class Imbalance

# %%
count_churn = pd.value_counts(df_clean['Churn'], sort =True)
count_churn.plot(kind = 'bar', rot=0)
plt.title("Barplot of Churn")
LABELS = ["Churn", "Not Churn"]
# Add labels and title
plt.xticks(range(2), LABELS)
plt.xlabel('Churn')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %%
## Get the Churn and the Not Churn dataset
churn = df_clean[df_clean['Churn']==1]
not_churn = df_clean[df_clean['Churn']==0]

# %%
print(churn.shape,not_churn.shape)
# Out:
# (948, 20) (4682, 20)

# %% [markdown]
# # Data Splitting

# %%
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Print the shapes of the split data to check
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (4504, 10)
# Shape of X_test: (1126, 10)
# Shape of y_train: (4504,)
# Shape of y_test: (1126,)

# %%
from imblearn.combine import SMOTETomek

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(y_train == 1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train == 0)))

# import SMOTE module from imblearn library
# pip install imblearn (if you don't have imblearn in your system)
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train.ravel())

print('After OverSampling, the shape of train_X: {}'.format(X_train_res.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))

print("After OverSampling, counts of label '1': {}".format(sum(y_train_res == 1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train_res == 0)))
# Out:
# Before OverSampling, counts of label '1': 763
# Before OverSampling, counts of label '0': 3741
#
# After OverSampling, the shape of train_X: (7482, 10)
# After OverSampling, the shape of train_y: (7482,)
#
# After OverSampling, counts of label '1': 3741
# After OverSampling, counts of label '0': 3741

# %% [markdown]
# # Import Needed Libraries

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LinearRegression
from xgboost import XGBClassifier
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import classification_report
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras.utils import to_categorical

# %% [markdown]
# #Decision Tree Model

# %%
# Fitting the Model and Accuracy
clf = DecisionTreeClassifier()
clf.fit(X_train_res, y_train_res.ravel())
dt_y_pred = clf.predict(X_test)
dt_accuracy = accuracy_score(y_test, dt_y_pred)
print("Accuracy:", dt_accuracy)
# Out:
# Accuracy: 0.9440497335701599

# %%
from sklearn.metrics import confusion_matrix, classification_report
# print classification report
print(classification_report(y_test, dt_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       941
#            1       0.80      0.89      0.84       185
#
#     accuracy                           0.94      1126
#    macro avg       0.89      0.92      0.90      1126
# weighted avg       0.95      0.94      0.95      1126

# %%
## Root Mean Squared Error for Decision Tree Model
from sklearn.metrics import mean_squared_error
import numpy as np
# y_test contains the true target values and y_pred contains the predicted target values
dt_mse = mean_squared_error(y_test, dt_y_pred)
dt_rmse = np.sqrt(dt_mse)
print("RMSE:", dt_rmse)
# Out:
# RMSE: 0.23653808663688844

# %%
from sklearn.metrics import confusion_matrix
# Compute the confusion matrix
dt_cm = confusion_matrix(y_test, dt_y_pred)
# Create a DataFrame for the confusion matrix
cm_dt = pd.DataFrame(dt_cm, index=['Actual Negative', 'Actual Positive'], columns=['Predicted Negative', 'Predicted Positive'])
# Plot the heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(cm_dt, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix Heatmap for Decision Tree')
plt.show()

# %% [markdown]
# #Naive Bayes

# %%
# Model Fitting and Accuracy
gb = GaussianNB()
gb.fit(X_train_res, y_train_res)
nb_y_pred = gb.predict(X_test)
accuracy_gb = accuracy_score(y_test, nb_y_pred)
print("Accuracy:", accuracy_gb)

# print classification report
print(classification_report(y_test, nb_y_pred))
# y_test contains the true target values and rf_y_pred contains the predicted target values
nb_mse = mean_squared_error(y_test, nb_y_pred)
nb_rmse = np.sqrt(nb_mse)

print("RMSE:", nb_rmse)
# Out:
# Accuracy: 0.6536412078152753
#               precision    recall  f1-score   support
#
#            0       0.93      0.63      0.75       941
#            1       0.29      0.75      0.42       185
#
#     accuracy                           0.65      1126
#    macro avg       0.61      0.69      0.58      1126
# weighted avg       0.82      0.65      0.70      1126
#
# RMSE: 0.5885225502771535

# %%
# Compute the confusion matrix
nb_cm = confusion_matrix(y_test, nb_y_pred)

# Create a DataFrame for the confusion matrix
cm_nb = pd.DataFrame(nb_cm, index=['Actual Negative', 'Actual Positive'], columns=['Predicted Negative', 'Predicted Positive'])

# Plot the heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(cm_nb, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix Heatmap for Naive Bayes')
plt.show()

# %% [markdown]
# #Random Forest

# %%
# Define the number of trees (n_estimators)
n_estimators = [100, 200, 500]
# Train and evaluate Random Forest classifiers with different numbers of trees
for n in n_estimators:
    # Create a Random Forest classifier
    rf = RandomForestClassifier(n_estimators=n)
    # Fit the classifier to the training data
    rf.fit(X_train_res, y_train_res)
    # Make predictions on the test data
    rf_y_pred = rf.predict(X_test)
    # Calculate and print the accuracy score
    RF_accuracy = accuracy_score(y_test, rf_y_pred)
    print(f"Accuracy with {n} trees: {RF_accuracy}")
    ## Root Mean Squared Error for Random Forest Model
from sklearn.metrics import mean_squared_error
import numpy as np

# y_test contains the true target values and rf_y_pred contains the predicted target values
rf_mse = mean_squared_error(y_test, rf_y_pred)
rf_rmse = np.sqrt(rf_mse)

print("RMSE:", rf_rmse)
# Out:
# Accuracy with 100 trees: 0.9733570159857904
# Accuracy with 200 trees: 0.9680284191829485
# Accuracy with 500 trees: 0.9689165186500888
# RMSE: 0.1763050803292724

# %%
# Compute the confusion matrix
rf_cm = confusion_matrix(y_test, rf_y_pred)
# Create a DataFrame for the confusion matrix
cm_rf = pd.DataFrame(rf_cm, index=['Actual Negative', 'Actual Positive'], columns=['Predicted Negative', 'Predicted Positive'])
# Plot the heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix Heatmap for Random Forest')
plt.show()

# %%
# print classification report
print(classification_report(y_test, rf_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       941
#            1       0.90      0.91      0.91       185
#
#     accuracy                           0.97      1126
#    macro avg       0.94      0.95      0.94      1126
# weighted avg       0.97      0.97      0.97      1126

# %% [markdown]
# ## Linear Separability Check

# %%
# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(X[Y == 0].iloc[:, 0], X[Y == 0].iloc[:, 1], color='red', label='Churn: No')
plt.scatter(X[Y == 1].iloc[:, 0], X[Y == 1].iloc[:, 1], color='blue', label='Churn: Yes')
# Add labels and legend
plt.xlabel('No Churn')
plt.ylabel('Churn')
plt.legend(loc='upper right')
# Show the plot
plt.show()

# %%
from sklearn.datasets import make_classification
# Generate a synthetic dataset
X, y = make_classification(n_features=2, n_redundant=0, n_informative=2,
                           n_clusters_per_class=1, random_state=42)

# Create a scatter plot of the data points with different colors for each class
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired, edgecolors='k')
plt.xlabel('Feature 1')

X = df_clean.iloc[:,:-1]
Y = df_clean['Churn']

plt.ylabel('Feature 2')
plt.title('Scatter Plot of the Data Points')
plt.show()

# %% [markdown]
# ## Support Vector Classifier

# %%
# Define the hyperparameters for each kernel
rbf_params = {'C': 1.0, 'gamma': 'scale'}
linear_params = {'C': 0.5, 'gamma': 'scale'}
poly_params = {'C': 0.1, 'gamma': 'scale', 'degree': 2}

# Train and evaluate SVC with RBF kernel
rbf_svc = SVC(kernel='rbf', **rbf_params)
rbf_svc.fit(X_train_res, y_train_res)
rbf_y_pred = rbf_svc.predict(X_test)
rbf_accuracy = accuracy_score(y_test, np.round(rbf_y_pred))
rbf_rmse = np.sqrt(mean_squared_error(y_test, rbf_y_pred))
print("RBF SVC - Accuracy:", rbf_accuracy)
print("RBF SVC - RMSE:", rbf_rmse)

# Train and evaluate SVC with Linear kernel
linear_svc = SVC(kernel='linear', **linear_params)
linear_svc.fit(X_train_res, y_train_res)
linear_y_pred = linear_svc.predict(X_test)
linear_accuracy = accuracy_score(y_test, np.round(linear_y_pred))
linear_rmse = np.sqrt(mean_squared_error(y_test, linear_y_pred))
print("Linear SVC - Accuracy:", linear_accuracy)
print("Linear SVC - RMSE:", linear_rmse)

# Train and evaluate SVC with Polynomial kernel
poly_svc = SVC(kernel='poly', **poly_params)
poly_svc.fit(X_train_res, y_train_res)
poly_y_pred = poly_svc.predict(X_test)
poly_accuracy = accuracy_score(y_test, np.round(poly_y_pred))
poly_rmse = np.sqrt(mean_squared_error(y_test, poly_y_pred))
print("Polynomial SVC - Accuracy:", poly_accuracy)
print("Polynomial SVC - RMSE:", poly_rmse)
# Out:
# RBF SVC - Accuracy: 0.7539964476021315
# RBF SVC - RMSE: 0.49598745185525467
# Linear SVC - Accuracy: 0.7442273534635879
# Linear SVC - RMSE: 0.5057397023533076
# Polynomial SVC - Accuracy: 0.6714031971580817
# Polynomial SVC - RMSE: 0.5732336372212627

# %%
# Assuming poly_y_pred contains continuous predictions or probabilities
threshold = 0.5
binary_y_pred = [1 if prob >= threshold else 0 for prob in rbf_y_pred]

# Now, print the classification report
print(classification_report(y_test, binary_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83       941
#            1       0.38      0.81      0.52       185
#
#     accuracy                           0.75      1126
#    macro avg       0.67      0.77      0.68      1126
# weighted avg       0.86      0.75      0.78      1126

# %%
# Compute the confusion matrix
rbf_cm = confusion_matrix(y_test, binary_y_pred)

# Create a DataFrame for the confusion matrix
cm_rbf = pd.DataFrame(rbf_cm, index=['Actual Negative', 'Actual Positive'], columns=['Predicted Negative', 'Predicted Positive'])

# Plot the heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(cm_rbf, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix Heatmap SVC Kernel (Radial)')
plt.show()

# %% [markdown]
# # XG Boost Mode

# %%
# Definition, Training and Evaluation of XGBoost classifier
xgb = XGBClassifier()
xgb.fit(X_train_res, y_train_res)
xgb_y_pred = xgb.predict(X_test)

# %%
## Model Evaluation: Accuracy and Root Mean Squared Error for XGBoost Model
from sklearn.metrics import mean_squared_error
import numpy as np

# y_test contains the true target values and xgb_y_pred contains the predicted target values
xgb_mse = mean_squared_error(y_test, xgb_y_pred)
xgb_rmse = np.sqrt(xgb_mse)

print("RMSE:", xgb_rmse)
xgb_accuracy = accuracy_score(y_test, xgb_y_pred)
print("XGBoost Accuracy:", xgb_accuracy)
# Out:
# RMSE: 0.21282169256012484
# XGBoost Accuracy: 0.9547069271758437

# %%
# Now, print the classification report
print(classification_report(y_test, xgb_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       941
#            1       0.89      0.83      0.86       185
#
#     accuracy                           0.95      1126
#    macro avg       0.93      0.91      0.92      1126
# weighted avg       0.95      0.95      0.95      1126

# %%
# Compute the confusion matrix
xgb_cm = confusion_matrix(y_test, xgb_y_pred)
# Create a DataFrame for the confusion matrix
cm_xgb = pd.DataFrame(xgb_cm, index=['Actual Negative', 'Actual Positive'], columns=['Predicted Negative', 'Predicted Positive'])
# Plot the heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(cm_xgb, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix Heatmap for XGBoost')
plt.show()

# %% [markdown]
# # KNN Model

# %%
knn = KNeighborsClassifier()
knn_fit = knn.fit(X_train_res, y_train_res)
knn_y_pred = knn.predict(X_test)

# %%
## Evaluation: Accuracy and Root Mean Squared Error for KNN Model
from sklearn.metrics import mean_squared_error
import numpy as np

# y_test contains the true target values and xgb_y_pred contains the predicted target values
knn_mse = mean_squared_error(y_test, knn_y_pred)
knn_rmse = np.sqrt(knn_mse)
print("RMSE:", knn_rmse)
knn_accuracy = accuracy_score(y_test, knn_y_pred)
print("knn Accuracy:",knn_accuracy)
# Out:
# RMSE: 0.44701496631161236
# knn Accuracy: 0.8001776198934281

# %%
# Now, print the classification report
print(classification_report(y_test, knn_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.79      0.87       941
#            1       0.44      0.86      0.59       185
#
#     accuracy                           0.80      1126
#    macro avg       0.71      0.83      0.73      1126
# weighted avg       0.88      0.80      0.82      1126

# %%
# Compute the confusion matrix
knn_cm = confusion_matrix(y_test, knn_y_pred)

# Create a DataFrame for the confusion matrix
cm_knn = pd.DataFrame(knn_cm, index=['Actual Negative', 'Actual Positive'], columns=['Predicted Negative', 'Predicted Positive'])

# Plot the heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(cm_knn, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix Heatmap for KNN')
plt.show()

# %% [markdown]
# # Logistic Regression

# %%
# Import the necessary libraries
from sklearn.linear_model import LogisticRegression
# Create the Logistic Regression model with default parameters
logreg_model = LogisticRegression()
# Train the model on the training data
logreg_model.fit(X_train_res, y_train_res)
# Make predictions on the test data
logreg_predictions = logreg_model.predict(X_test)

# Now, print the classification report
print(classification_report(y_test, logreg_predictions))
# Calculate the root mean squared error (RMSE)
rmse = np.sqrt(mean_squared_error(y_test, logreg_predictions))
print("RMSE:", rmse)
log_accuracy = accuracy_score(y_test, logreg_predictions)
print("log Accuracy:",log_accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.73      0.83       941
#            1       0.37      0.81      0.51       185
#
#     accuracy                           0.74      1126
#    macro avg       0.66      0.77      0.67      1126
# weighted avg       0.85      0.74      0.77      1126
#
# RMSE: 0.5083669392651661
# log Accuracy: 0.7415630550621669

# %%
# Compute the confusion matrix of the Log Regression
lr_cm = confusion_matrix(y_test, logreg_predictions)
# Create a DataFrame for the confusion matrix
cm_lr = pd.DataFrame(lr_cm, index=['Actual Negative', 'Actual Positive'], columns=['Predicted Negative', 'Predicted Positive'])
# Plot the heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix Heatmap for Logistic Regression')
plt.show()

# %% [markdown]
# # Deep Learning - Artificial Neural Network

# %%
# Determine the number of classes
num_classes = np.max(y_train_res) + 1
# Convert y_train_res and y_test to one-hot encoded format for multi-class classification
y_train_res_encoded = to_categorical(y_train_res, num_classes=num_classes)
y_test_encoded = to_categorical(y_test, num_classes=num_classes)
# Build the deep learning ANN model
deep_ann = Sequential()
deep_ann.add(Dense(128, activation='relu', input_dim=X_train_res.shape[1]))
deep_ann.add(Dense(64, activation='relu'))
deep_ann.add(Dense(32, activation='relu'))
deep_ann.add(Dense(16, activation='relu'))
deep_ann.add(Dense(num_classes, activation='softmax'))  # Output layer with the number of classes
# Compile the model with appropriate loss and optimizer for multi-class classification
deep_ann.compile(optimizer=Adam(learning_rate=0.001),
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])
# Train the model
deep_ann.fit(X_train_res, y_train_res_encoded, epochs=10, batch_size=32, verbose=1)
# Make predictions on the test data
deep_ann_y_pred_prob = deep_ann.predict(X_test)
deep_ann_y_pred = np.argmax(deep_ann_y_pred_prob, axis=1)  # Convert probabilities to class labels
# Generate the classification report
target_names = [f"Class {i}" for i in range(num_classes)]
classification_rep = classification_report(y_test, deep_ann_y_pred, target_names=target_names)
print("Classification Report:")
print(classification_rep)
# Calculate accuracy
ann_accuracy = accuracy_score(y_test, deep_ann_y_pred)
print("ANN Accuracy:", ann_accuracy)
# Out:
# Epoch 1/10
# 234/234 [==============================] - 1s 2ms/step - loss: 0.6081 - accuracy: 0.6677
# Epoch 2/10
# 234/234 [==============================] - 1s 2ms/step - loss: 0.5158 - accuracy: 0.7471
# Epoch 3/10
# 234/234 [==============================] - 1s 2ms/step - loss: 0.4880 - accuracy: 0.7637
# Epoch 4/10
# 234/234 [==============================] - 1s 2ms/step - loss: 0.4802 - accuracy: 0.7741
# Epoch 5/10
# 234/234 [==============================] - 1s 2ms/step - loss: 0.4648 - accuracy: 0.7855
# Epoch 6/10
# 234/234 [==============================] - 1s 2ms/step - loss: 0.4672 - accuracy: 0.7801
# Epoch 7/10
# 234/234 [==============================] - 1s 2ms/step - loss: 0.4494 - accuracy: 0.7930
# Epoch 8/10
# 234/234 [==============================] - 1s 2ms/step - loss: 0.4391 - accuracy: 0.7980
# Epoch 9/10
# 234/234 [==============================] - 1s 2ms/step - loss: 0.4381 - accuracy: 0.8031
# Epoch 10/10
# ...

# %%
# Calculate the root mean squared error (RMSE)
rmse = np.sqrt(mean_squared_error(y_test, deep_ann_y_pred))
print("RMSE:", rmse)
# Out:
# RMSE: 0.395354911714394

# %%
# Compute the confusion matrix
ann_cm = confusion_matrix(y_test, deep_ann_y_pred)
# Create a DataFrame for the confusion matrix
cm_ann = pd.DataFrame(ann_cm, index=['Actual Negative', 'Actual Positive'], columns=['Predicted Negative', 'Predicted Positive'])
# Plot the heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(cm_ann, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix Heatmap for ANN')
plt.show()

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# Assuming you have X_train, X_test, y_train, y_test as your data

# Build the DNN model
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_dim=X_train.shape[1]),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=0)

# Make predictions on the test data
y_pred_prob = model.predict(X_test)
y_pred = np.round(y_pred_prob).astype(int)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy:", accuracy)

# Print the classification report
print(classification_report(y_test, y_pred))
# Out:
# 36/36 [==============================] - 0s 4ms/step
# Test Accuracy: 0.88898756660746
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       941
#            1       0.79      0.44      0.56       185
#
#     accuracy                           0.89      1126
#    macro avg       0.85      0.71      0.75      1126
# weighted avg       0.88      0.89      0.88      1126

# %%
# Build the DNN model
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_dim=X_train.shape[1]),
    layers.Dropout(0.3),  # Add dropout for regularization
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.3),  # Add dropout for regularization
    layers.Dense(1, activation='sigmoid')
])

# Compile the model with custom learning rate and optimizer
learning_rate = 0.001
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])



# Train the model with a batch size and epochs
batch_size = 32
epochs = 20
model.fit(X_train_res, y_train_res, epochs=epochs, batch_size=batch_size, verbose=1)

# Make predictions on the test data
y_pred_prob = model.predict(X_test)
y_pred = np.round(y_pred_prob).astype(int)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
                 print("Test Accuracy:", accuracy)

# Print the classification report
print(classification_report(y_test, y_pred))

# %%
# Define the models and their corresponding accuracy scores
models = ['ANN', 'KNN', 'SVR_RBF', 'LR', 'RF', 'DT', 'XGBoost', 'NBayes']
accuracy_scores = [ann_accuracy, knn_accuracy, rbf_accuracy, log_accuracy, RF_accuracy, dt_accuracy, xgb_accuracy,  accuracy_gb]
# Plot the bar chart
plt.bar(models, accuracy_scores)
# Add labels and title
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Model Comparison')
# Display the plot
plt.show()
